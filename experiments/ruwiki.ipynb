# %% [markdown]
# Вывод: у меня действительно есть вся Википедия, но она структурирована не очень хорошо.
#
# Наверное, будет сильно удобнее выкачать себе нужный кусочек википедии в процессе.

# %%
import os
import sys

# %%
p = 'C:/Users/ddale/Downloads/NLP/taxonomy-enrichment-data/wikipedia-ru-2018.txt'

# %%
from collections import Counter

# %%
from tqdm.auto import tqdm, trange

# %%
chars = Counter()

with open(p, 'r', encoding='utf-8') as f:
    for i in trange(1000000):
        line = next(f)
        chars.update(line)

# %%
len(chars)
# Out:
# 2940

# %%
t = ''.join(sorted(chars.keys()))
t
# Out:
# '\n !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~\x84\x85\x86\x8f\x92\x96\xa0¡¢£¤¥¦§¨©«¬\xad®¯°±²³´µ·¹º»¼½¾¿ÀÁÂÃÄÅÆÇÈÉÊÌÍÎÏÐÑÒÓÔÕÖ×ØÙÚÛÜÝÞßàáâãäåæçèéêëìíîïðñòóôõö÷øùúûüýþÿĀāĂăĄąĆćĈĉċČčďĐđĒēĔĕėĘęĚěĜĝĞğġĢģĤĥĦħĩĪīĭĮįİıĲĳĴĵĶķĺļĽľŁłńņŇňŊŋŌōŎŏŐőŒœŕŗřŚśŜŝŞşŠšŢţŤťũŪūŬŭŮůŰűųŷŸŹźŻżŽžſƀƁƆƇƉƊƎƏƐƑƒƓƔƘƙƜƝƟơƣƩƮưƱƲƵƶƷǀǁǍǎǏǐǒǔǝǣǥǧǫǯǰǵǷǺǻȁȃȋȘșȚțȝȧȯȳɐɑɒɓɔɕɖɗɘəɚɛɜɝɟɡɣɤɥɦɨɪɫɯɲɳɵɶɷɸɹɺɽɾʁʂʃʆʈʉʊʌʎʏʐʑʒʔʕʘʙʜʣʤʥʦʧʨʰʲʷʹʻʼʽʾʿˀˁ˅ˆˈˉˊˌːˑ˘˚˜ˤ˳̢̠̣̤̥̦̪̯̲͍̀́̂̃̄̅̆̈̉̊̌̏̑̓͂͡ͻͿ΄ΆΈΉΌΏΐΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩΪάέήίΰαβγδεζηθικλμνξοπρςστυφχψωϊϋόύώϑϒϘϚϛϜϟϡϦϧϩϪϫϰϱϲϳϹЁЂЃЄЅІЇЈЉЊЋЌЎЏАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяѐёђѓєѕіїјљњћќѝўџѠѡѢѣѤѥѦѧѨѩѪѫѬѮѯѰѲѳѴѵѹѾѿ҂҃҄ҍҐґҒғҔҕҖҗҘҙҚқҜҟҠҡҢңҤҥҧҪҫҬҭҮүҰұҲҳҵҶҷҹҺһӀӁӂӃӄӅӆӇӈӏӐӑӒӓӔӕӖӗӘәӝӟӠӡӢӣӥӦӧӨөӫӬӭӮӯӰӱӲӳӵӶӷӹӼӽԒԓԠԡԢԣԫԱԲԳԴԵԶԷԸԹԺԻԼԾԿՀՁՂՃՄՅՆՇՈՉՊՋՌՍՎՏՐՑՒՓՔՕՖաբգդեզէըթժիլխծկհղճմյնշոչպջռսվտրցւփքօև։֏ְֲִֵֶַָֹֻּ֣֔־ֿׁׂאבגדהוזחטיךכלםמןנסעףפץצקרשתװױײ׳״،؟ءآأؤإئابةتثجحخدذرزسشصضطظعغـفقكلمنهوىئًٌٍَُِّْٰٙٹټپځڅچڈډڑړږژښڤڥکڭڮگڼہۇیۍےܐܓܗܘܢܦܪܸܵ
# ...

# %%
'а́' in t
# Out:
# False

# %%
lol = 'Литва́'
len(lol)
# Out:
# 6

# %%
kek = '́'

# %%
kek in 'Респу́блика'
# Out:
# True

# %%
lol[5]
# Out:
# '́'

# %%
with open(p, 'r', encoding='utf-8') as f:
    for i in trange(10):
        line = next(f)
        print(line)
# Out:
# ...
# Литва
#
#
#
# Литва́ (), официальное название — Лито́вская Респу́блика () — государство, расположенное в Северной Европе (одна из стран Балтии). Столица страны — Вильнюс.
#
#
#
# Площадь — 65 300 км². Протяжённость с севера на юг 280 км, а с запада на восток 370 км Путёвые заметки. География Литвы . Население составляет 3 054 000 человек Предварительные итоги переписи в официальном пресс-релизе Департамента статистики.  — по этим показателям является крупнейшим прибалтийским государством. Имеет выход к Балтийскому морю, расположена на его восточном побережье. Береговая линия составляет всего 99 км (наименьший показатель среди прибалтийских государств). На севере граничит с Латвией, на юго-востоке — с Белоруссией, на юго-западе — c Польшей и Калининградской областью России.
#
#
#
# Член ООН с 1991 года, ЕС и НАТО — с 2004 года. Входит в Шенгенскую зону и Еврозону.
#
#
#
# ...

# %%
"BDF6040136E94B3E95945A89D1762256".lower()
# Out:
# 'bdf6040136e94b3e95945a89d1762256'
